# %%
import numpy
import matplotlib.pyplot as plt
year=[2014,2015,2016,2017,2018,2019,2020]
percentb=[91,92,94,96,93,95,97]
percentg=[90,89,96,93,95,92,94]
plt.plot( year, percentb , color='g')
plt.plot( year, percentg, color='b')
plt.ylabel("Percentage")
plt.xlabel("Year")
plt.title("Boys Vs Girls Percentage")
plt.legend(('boys','girls'),loc='upper right')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
label=["Tisha", "Garvita","Rahul","Liza","Kamaal","Shantanu","Vaibhav"]
DOB=[5,5,4,12,24,21,10]
index=np.arange(len(label))
plt.bar(index,DOB)
plt.xlabel("Student Name")
plt.ylabel("DOB")
plt.xticks(index,label,rotation=30)
plt.title("DOB Vs Students")
plt.legend("DOB")
plt.show()




Create a pie chart and bar graph horizontal of following data. Add suitable labels.
City Population
Delhi 23456123
Mumbai 20083104
Bangalore 18456123
Hyderabad 13411093

# %%
#HISTOGRAM

import numpy as np
import matplotlib.pyplot as plt
plt.hist([5,15,25,35,45,55], bins=[0,10,20,30,40,50,60], weights=[20, 10, 45, 33, 6, 8], facecolor="yellow", edgecolor="black")
plt.xlabel("Frequency")
plt.ylabel("Values")
plt.title("HISTOGRAM")
plt.show()

# %%
#PIE CHARTS
import matplotlib.pyplot as plt
labels='c1','c2','c3','c4'
votes=[315,210,245,130]
sizes=votes
color=['r','cyan', 'orange', 'gold']
#exp=(0.1,0.2,0.3,0.4)
plt.pie(sizes,explode=exp,labels=labels,colors=color,shadow=True,startangle=140,autopct='%.3f%%')
plt.axis('equal')
plt.show()

# %%
Create a pie chart and bar graph horizontal of following data. Add suitable labels.
City Population
Delhi 23456123
Mumbai 20083104
Bangalore 18456123
Hyderabad 13411093

# %%
#BOX PLOT


import matplotlib.pyplot as plt
value1=[72,76,24,40,57,62,75,78,31,32]
value2=[62,5,91,25,36,32,96,95,30,90]
value3=[23,89,12,78,72,89,25,69,68,86]
value4=[99,73,70,16,81,61,88,98,10,87]
box_plot_data=[value1,value2,value3,value4]
box=plt.boxplot(box_plot_data,vert=1,patch_artist=True,labels=['course1','course2','course3','course4'])
colors = ['cyan', 'lightblue', 'lightgreen', 'tan']
for patch,color in zip(box['boxes'],colors):
    patch.set_facecolor(color)
plt.show()

# %%
import matplotlib.pyplot as plt
weight1=[93.3,67,62.3,43,71,71.8]
height1=[116.3,110.7,124.8,176.3,137.1,113.9]
plt.scatter(weight1,height1,color='green',marker='x')
plt.xlabel('weight', fontsize=16)
plt.ylabel('height', fontsize=16)
plt.title('scatter plot - height vs weight',fontsize=20)
plt.show()
